# %% [markdown]
# ### Exercise 1
# Ask a user for 5 names and place each one in to a list called <i>names</i>. Then, print <i>names</i>.

# %%
name1 = input("please enter name 1:")
name2 = input("please enter name 2:")
name3 = input("please enter name 3:")
name4 = input("please enter name 4:")
name5 = input("please enter name 5:")

names = []

names.insert(0,name1)
names.insert(1,name2)
names.insert(2,name3)
names.insert(3,name4)
names.insert(4,name5)

print(names)
# Out:
# please enter name 1:Lisa
# please enter name 2:Paul
# please enter name 3:Frank
# please enter name 4:Marina
# please enter name 5:ORegeon
# ['Lisa', 'Paul', 'Frank', 'Marina', 'ORegeon']

# %% [markdown]
# ### Exercise 2
# Print out a randomly selected name in the names list from exercise 1.

# %%
import random as random

name = random.choice(names)
print(name)
# Out:
# ORegeon

# %% [markdown]
# ### Exercise 3:
# Fix bugs in the next cell.  It is trying to create a list for even numbers between two numbers provided by a user.

# %%
no1 = input("Enter a starting number: ")
no2 = input("Enter an ending number: ")

no1 = int(no1)
no2 = int(no2)

numbers = []
evens = []

for i in range(no1, no2) :
    numbers.append(i) 
    if (i%2 == 0):    # even number
        evens.append(i)
    
print(numbers)    
print(evens)
# Out:
# Enter a starting number: 1
# Enter an ending number: 10
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [2, 4, 6, 8]

# %% [markdown]
# ### Exercise 4
# Finish writing a program to generate 10 random numbers between 1 and 100 and save it to a list.
# Finally, print out the original numbers followed by the smallest, largest, and average number.

# %%
import random as rand

numbers = []
total = 0

for i in range(1, 11) :
    numb = rand.randint(1, 100)
    total += numb
    numbers.append(numb)

    
# some code needed here to find the smallest, largest, and average number

org_numbs = numbers.copy()

numbers.sort()
largest = numbers[-1]
smallest = numbers[0]


def average():
    return sum(numbers)/len(numbers)

avg = average()


print(f"Org Numbers are {org_numbs}")
print(f"Sorted numbers are {numbers}")
print(f"Largest number is {largest}")
print(f"Smallest number is {smallest}")
print(f"Average is {avg}")
# Out:
# Org Numbers are [100, 59, 70, 50, 19, 100, 45, 16, 42, 1]
# Sorted numbers are [1, 16, 19, 42, 45, 50, 59, 70, 100, 100]
# Largest number is 100
# Smallest number is 1
# Average is 50.2

# %% [markdown]
# ### Exercise 5
#
# Write a function called <b>draw_triangle()</b> to draw a right triangle where the base of the triangle is the number passed in as an arguement. Call <b>draw_triangle()</b> to show it works.
#
# e.g. <b>draw_triangle(7)</b> draws as below:
#
#     *
#     **
#     ***
#     ****
#     *****
#     ******
#     *******

# %%
# write code for draw_triangle() function
def draw_triangle(x):
    for i in range(1,x):
        print("*"*i)

# %%
base = int(input("Enter a number: "))

draw_triangle(base)
# Out:
# Enter a number: 100
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************
# *************************
# **************************
# ***************************
# ****************************
# *****************************
# ******************************
# *******************************
# ********************************
# *********************************
# **********************************
# ***********************************
# ************************************
# *************************************
# **************************************
# ***************************************
# ****************************************
# *****************************************
# ******************************************
# *******************************************
# ********************************************
# *********************************************
# **********************************************
# ***********************************************
# ************************************************
# *************************************************
# **************************************************
# ***************************************************
# ****************************************************
# *****************************************************
# ******************************************************
# *******************************************************
# ********************************************************
# *********************************************************
# **********************************************************
# ***********************************************************
# ************************************************************
# *************************************************************
# **************************************************************
# ***************************************************************
# ****************************************************************
# *****************************************************************
# ******************************************************************
# *******************************************************************
# ********************************************************************
# *********************************************************************
# **********************************************************************
# ***********************************************************************
# ************************************************************************
# *************************************************************************
# **************************************************************************
# ***************************************************************************
# ****************************************************************************
# *****************************************************************************
# ******************************************************************************
# *******************************************************************************
# ********************************************************************************
# *********************************************************************************
# **********************************************************************************
# ***********************************************************************************
# ************************************************************************************
# *************************************************************************************
# **************************************************************************************
# ***************************************************************************************
# ****************************************************************************************
# *****************************************************************************************
# ******************************************************************************************
# *******************************************************************************************
# ********************************************************************************************
# *********************************************************************************************
# **********************************************************************************************
# ***********************************************************************************************
# ************************************************************************************************
# *************************************************************************************************
# **************************************************************************************************
# ***************************************************************************************************
